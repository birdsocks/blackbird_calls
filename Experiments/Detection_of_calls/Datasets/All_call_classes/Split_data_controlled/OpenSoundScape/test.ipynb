# %%
import bioacoustics_model_zoo as bmz
from pathlib import Path
model = bmz.Perch2()
model.device = "cpu"
# Out:
# 2026-01-23 16:50:45.643357: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 363601920 exceeds 10% of free system memory.
# /home/Shelby/miniconda3/envs/BlackbirdOP_py312/lib/python3.12/site-packages/opensoundscape/ml/cnn.py:599: UserWarning:
#                     This architecture is not listed in opensoundscape.ml.cnn_architectures.ARCH_DICT.
#                     It will not be available for loading after saving the model with .save() (unless using pickle=True).
#                     To make it re-loadable, define a function that generates the architecture from arguments: (n_classes, n_channels)
#                     then use opensoundscape.ml.cnn_architectures.register_architecture() to register the generating function.
#
#                     The function can also set the returned object's .constructor_name to the registered string key in ARCH_DICT
#                     to avoid this warning and ensure it is reloaded correctly by opensoundscape.ml.load_model().
#
#                     See opensoundscape.ml.cnn_architectures module for examples of constructor functions
#
#   warnings.warn(
# /home/Shelby/miniconda3/envs/BlackbirdOP_py312/lib/python3.12/site-packages/opensoundscape/ml/cnn.py:623: UserWarning: Failed to detect expected # input channels of this architecture.Make sure your architecture expects the number of channels equal to `channels` argument 1). Pytorch architectures generally expect 3 channels by default.
#   warnings.warn(

# %%
audio_dir = "/mnt/class_data/Shelby/One_Minute_Audio"
directory = Path(audio_dir)

# find all the .WAV files in the directory
wav_files = list(directory.rglob("*.WAV"))
print(f"Found {len(wav_files)} .WAV files.")
example = wav_files[0] 
print(example)
# Out:
# Found 111 .WAV files.
# /mnt/class_data/Shelby/One_Minute_Audio/SL43 Trial 1_trim.WAV

# %%
model.predict([example])
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 2026-01-23 16:50:49.079928: I external/local_xla/xla/service/service.cc:163] XLA service 0x7e829406dcb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-23 16:50:49.079954: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): GRID A100X-10C, Compute Capability 8.0
# 2026-01-23 16:50:49.428776: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-23 16:50:49.466288: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
